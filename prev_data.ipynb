# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raw = pd.read_csv('/home/kshgrk/huen/main/btc.csv')

# %%
for i in raw.columns:
    print(i)
# Out:
# time
# AdrActCnt
# AdrBal1in100KCnt
# AdrBal1in100MCnt
# AdrBal1in10BCnt
# AdrBal1in10KCnt
# AdrBal1in10MCnt
# AdrBal1in1BCnt
# AdrBal1in1KCnt
# AdrBal1in1MCnt
# AdrBalCnt
# AdrBalNtv0.001Cnt
# AdrBalNtv0.01Cnt
# AdrBalNtv0.1Cnt
# AdrBalNtv100Cnt
# AdrBalNtv100KCnt
# AdrBalNtv10Cnt
# AdrBalNtv10KCnt
# AdrBalNtv1Cnt
# AdrBalNtv1KCnt
# AdrBalNtv1MCnt
# AdrBalUSD100Cnt
# AdrBalUSD100KCnt
# AdrBalUSD10Cnt
# AdrBalUSD10KCnt
# AdrBalUSD10MCnt
# AdrBalUSD1Cnt
# AdrBalUSD1KCnt
# AdrBalUSD1MCnt
# AssetEODCompletionTime
# BlkCnt
# BlkSizeMeanByte
# BlkWghtMean
# BlkWghtTot
# CapAct1yrUSD
# CapMVRVCur
# CapMVRVFF
# CapMrktCurUSD
# CapMrktFFUSD
# CapRealUSD
# DiffLast
# DiffMean
# FeeByteMeanNtv
# FeeMeanNtv
# FeeMeanUSD
# FeeMedNtv
# FeeMedUSD
# FeeTotNtv
# FeeTotUSD
# FlowInExNtv
# FlowInExUSD
# FlowOutExNtv
# FlowOutExUSD
# FlowTfrFromExCnt
# HashRate
# HashRate30d
# IssContNtv
# IssContPctAnn
# IssContPctDay
# IssContUSD
# IssTotNtv
# IssTotUSD
# NDF
# NVTAdj
# NVTAdj90
# NVTAdjFF
# ...

# %%
raw.PriceUSD
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 4768    36271.050265
# 4769    36659.725221
# 4770    36952.586773
# 4771    36825.824599
# 4772             NaN
# Name: PriceUSD, Length: 4773, dtype: float64

# %%
np.corrcoef(raw.PriceUSD, raw.AdrBal1in10BCnt)[0][1]
# Out:
# nan

# %%
raw = raw[1000:]

# %%
raw.describe()
# Out:
#           AdrActCnt  AdrBal1in100KCnt  AdrBal1in100MCnt  AdrBal1in10BCnt  \
# count  3.772000e+03       3772.000000      3.772000e+03     3.772000e+03
# mean   5.037552e+05       9072.887593      1.231517e+06     6.648384e+06
# std    3.486827e+05        488.507670      7.643126e+05     5.568328e+06
# min    9.955000e+03       5735.000000      1.417360e+05     2.439120e+05
# 25%    1.708332e+05       8930.000000      5.284102e+05     1.388192e+06
# 50%    5.371305e+05       9161.500000      1.202644e+06     5.091846e+06
# 75%    7.694298e+05       9336.250000      1.966980e+06     1.183146e+07
# max    1.366494e+06      10410.000000      2.282669e+06     1.642766e+07
#
#        AdrBal1in10KCnt  AdrBal1in10MCnt  AdrBal1in1BCnt  AdrBal1in1KCnt  \
# count      3772.000000      3772.000000    3.772000e+03     3772.000000
# mean        958.143690    343325.932131    3.179598e+06       58.310445
# std          75.418662    129367.651001    2.392159e+06       12.633141
# ...

# %%
raw['PriceUSD'].unique()
# Out:
# array([5.14368591e+00, 5.03407054e+00, 5.00706260e+00, ...,
#        3.69525868e+04, 3.68258246e+04,            nan])

# %%
raw['HashRate'].unique().shape
# Out:
# (3358,)

# %%
raw = raw[:-1]

# %%
raw.shape
# Out:
# (3772, 144)

# %%
for i in raw.columns[1:]:
    x = np.corrcoef(raw.PriceUSD, raw[i])[0][1]
    if(x<=0.5 and x>0):
        try:
            raw.drop([i], axis=1, inplace=True)
        except:
            print(i)
    elif(x>=-0.5 and x<0):
        try:
            raw.drop([i], axis=1, inplace=True)
        except:
            print(i)
    else:
        print(x)
# Out:
# 0.6545083935355841
# 0.6438622612058772
# 0.7373332355979857
# 0.5102392989255019
# 0.5341310651856257
# 0.6957072494119967
# 0.7657917140346393
# 0.7535221413543871
# 0.7037921970645704
# 0.6785595997234898
# 0.5992875662322644
# 0.576555053692195
# nan
# 0.9268626156817991
# 0.9770197600253047
# 0.8795569772540527
# 0.9809875366917925
# 0.9975336833024271
# 0.8469802883901262
# 0.9515499626527397
# 0.9915047399532639
# 0.7539250745664282
# 0.5795855786622875
# 0.99825237367953
# 0.9998059328899268
# 0.9999651283399704
# 0.9571982948929622
# 0.829709925318402
# 0.8296672368345998
# 0.5510994884164782
# 0.5208854073315283
# 0.8611472057121439
# 0.8633002493436203
# 0.8296724156885863
# 0.8306340518261057
# -0.5212068076541726
# 0.9574807912738003
# -0.5212068076541726
# 0.9574807912738003
# nan
# 1.0
# 0.9990219680087792
# nan
# 0.9985038800397908
# 0.9990219680087792
# 0.881976260774055
# -0.5249729795630077
# 0.9517144087687103
# 0.6230229211265691
# 0.5250649625087593
# ...

# %%
raw.head(15)
# Out:
#             time  AdrActCnt  AdrBal1in100MCnt  AdrBal1in10BCnt  \
# 1000  2011-09-30    13620.0          141845.0         243912.0
# 1001  2011-10-01    13286.0          141736.0         244049.0
# 1002  2011-10-02    11856.0          141897.0         244314.0
# 1003  2011-10-03    14031.0          141982.0         244604.0
# 1004  2011-10-04    13371.0          141903.0         244768.0
# 1005  2011-10-05    13475.0          142123.0         245195.0
# 1006  2011-10-06    14660.0          142001.0         245284.0
# 1007  2011-10-07    13622.0          142054.0         245574.0
# 1008  2011-10-08    12331.0          142258.0         245840.0
# 1009  2011-10-09    12398.0          142705.0         246508.0
# 1010  2011-10-10    13498.0          142911.0         246968.0
# 1011  2011-10-11    13852.0          143331.0         247773.0
# 1012  2011-10-12    13370.0          143505.0         248262.0
# 1013  2011-10-13    11340.0          143887.0         248836.0
# ...

# %%
raw.drop(['ReferenceRateETH'], 1, inplace=True)
# Out:
# /tmp/ipykernel_4412/561032415.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   raw.drop(['ReferenceRateETH'], 1, inplace=True)

# %%
target = raw.PriceUSD

# %%
raw.drop(['PriceUSD'], 1, inplace=True)
# Out:
# /tmp/ipykernel_4412/1344895271.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   raw.drop(['PriceUSD'], 1, inplace=True)

# %%
target = target[3:]

# %%
target.shape
# Out:
# (3769,)

# %%
#raw = raw[:-3]

# %%
raw.shape
# Out:
# (3772, 85)

# %%
raw.head(7)
# Out:
#             time  AdrActCnt  AdrBal1in100MCnt  AdrBal1in10BCnt  \
# 1000  2011-09-30    13620.0          141845.0         243912.0
# 1001  2011-10-01    13286.0          141736.0         244049.0
# 1002  2011-10-02    11856.0          141897.0         244314.0
# 1003  2011-10-03    14031.0          141982.0         244604.0
# 1004  2011-10-04    13371.0          141903.0         244768.0
# 1005  2011-10-05    13475.0          142123.0         245195.0
# 1006  2011-10-06    14660.0          142001.0         245284.0
#
#       AdrBal1in10KCnt  AdrBal1in10MCnt  AdrBal1in1BCnt  AdrBalCnt  \
# 1000            747.0         110940.0        219206.0   533657.0
# 1001            747.0         110801.0        219219.0   533893.0
# 1002            749.0         110868.0        219436.0   534217.0
# 1003            752.0         110980.0        219595.0   534577.0
# 1004            760.0         110854.0        219626.0   535029.0
# ...

# %%
for i in raw.columns:
    raw[i+'OneUp'] = raw[i].shift(periods=-1)
    raw[i+'TwoUp'] = raw[i].shift(periods=-2)
# Out:
# /tmp/ipykernel_4412/1789721369.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   raw[i+'OneUp'] = raw[i].shift(periods=-1)
# /tmp/ipykernel_4412/1789721369.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   raw[i+'TwoUp'] = raw[i].shift(periods=-2)
# ...

# %%
raw.shape
# Out:
# (3772, 255)

# %%
df.head(1), df.tail(1)
# Out:
# (            time  AdrActCnt  AdrBal1in100MCnt  AdrBal1in10BCnt  \
#  1000  2011-09-30    13620.0          141845.0         243912.0
#
#        AdrBal1in10KCnt  AdrBal1in10MCnt  AdrBal1in1BCnt  AdrBalCnt  \
#  1000            747.0         110940.0        219206.0   533657.0
#
#        AdrBalNtv0.001Cnt  AdrBalNtv0.01Cnt  ...  SplyMiner1HopAllUSDOneUp  \
#  1000           243754.0          218308.0  ...              1.563609e+07
#
#        SplyMiner1HopAllUSDTwoUp  TxTfrCntOneUp  TxTfrCntTwoUp  \
#  1000              1.556625e+07        12139.0        11165.0
#
#        TxTfrValAdjUSDOneUp  TxTfrValAdjUSDTwoUp  TxTfrValMeanUSDOneUp  \
#  1000        596247.510904        464700.046277            172.885343
#
#        TxTfrValMeanUSDTwoUp  TxTfrValMedUSDOneUp  TxTfrValMedUSDTwoUp
#  1000            144.708429             5.087383             5.007063
#
#  [1 rows x 255 columns],
#              time  AdrActCnt  AdrBal1in100MCnt  AdrBal1in10BCnt  \
# ...

# %%
target = raw['PriceUSD'].iloc[1000:4770]

# %%
3770*0.2
# Out:
# 754.0

# %%
3770-754
# Out:
# 3016

# %%
# df.drop(['time'], 1, inplace=True)
df.drop(['timeOneUp'], 1, inplace=True)
df.drop(['timeTwoUp'], 1, inplace=True)
# Out:
# /tmp/ipykernel_4412/4272280371.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['timeOneUp'], 1, inplace=True)
# /tmp/ipykernel_4412/4272280371.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['timeTwoUp'], 1, inplace=True)

# %%
x_train = df.iloc[:3016]
x_test = target[:3016]
y_train = df.iloc[3016:]
y_test = target.iloc[3016:]

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3016, 252), (3016,), (754, 252), (754,))

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.00001)
svr_rbf.fit(x_train, x_test)
# Out:
# SVR(C=1000.0, gamma=1e-05)

# %%
svr_rbf.score(y_train, y_test)
# Out:
# -2.1956511421418874

# %%
svr_rbf.score(x_train, x_test)
# Out:
# 0.08664413593893139
